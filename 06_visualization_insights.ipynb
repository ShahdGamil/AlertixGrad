# %% [markdown]
# # Visualization & Insights Notebook
#
# This notebook generates comprehensive visualizations and insights.
#
# ## Objectives:
# - Class distribution bar chart
# - Bounding box size distribution
# - Aspect ratio distribution
# - Image resolution distribution
# - Labeled image sample grid
# - Augmentation preview samples
# - Train/Validation/Test split statistics
