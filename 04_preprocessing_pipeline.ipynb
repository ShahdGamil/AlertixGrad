# %% [markdown]
# # Preprocessing Pipeline Notebook
#
# This notebook applies preprocessing compatible with YOLOv8m best practices.
#
# ## Objectives:
# - Resize images to 640x640
# - Normalize pixel values
# - Auto-orient images using EXIF metadata
# - Preserve aspect ratio using letterboxing
# - Convert images to efficient training format
# - Enable dataset caching for faster GPU training
